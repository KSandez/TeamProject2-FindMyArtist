# %%
# Imports for selenium
import re
import requests
import math
import json
import pandas as pd
from pprint import pprint
from bs4 import BeautifulSoup as bs
from splinter import Browser

def init_browser():   
    # Chrome driver
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
"""
This function is to parse out content using a regular expression pattern from a string.
<param>regex_pattern</param>
<param>string</param>
"""
def parse_definition(regex_pattern, string):
    result = re.compile(regex_pattern, flags=re.MULTILINE|re.DOTALL)
    # Checking if the patten works for the string
    if not result.search(string):
        return "None"
    else:
        return result.search(string).group(1)

# %%
def artist_code(artist):
    browser = init_browser()
    # URL for queries
    url = f'https://www.songkick.com/search?utf8=✓&type=initial&query={artist.replace(" ", "+")}'
    browser.visit(url)
    html = browser.html
    soup = bs(html, "html.parser")
    # Find the href for the URL with the page link
    container = soup.find("div", class_="sticky-container")
    row = container.find("div", class_="row")
    col = row.find("div", class_="col-8 primary")
    ul = col.find("ul")
    page_link = ul.find("a", class_="thumb")["href"]
    # Running the function
    artist_code = parse_definition('/artists/(\\d+)-', str(page_link))
    # Returns the artist code 
    return artist_code

# %%
# This will create a DB that will be thrown into a MongoDB to use
def concert_info(artist_code):
    # Initialzing Python dictionary
    concert_info = {}
    # Lists to store info to append to dictionary
    base_artist = []
    base_artist.append(artist_code)
    event_number = []
    event_name = []
    popularity = []
    location = []
    longitude = []
    latitude = []
    city = []
    start_date = []
    start_time = []
    for x in range(len(base_artist)):
        base_url = "https://api.songkick.com/api/3.0/artists/"+str(base_artist[x])+"/gigography.json?apikey=ORhDmrgUGkhdnXgP"+"&page=1"
        base_artist_2 = base_artist[x]
        total_entries = requests.get(base_url).json()['resultsPage']['totalEntries']
        pages = total_entries/50
        total_pages = math.ceil(pages)
        print('PRINTING EVENTS FOR ARTIST: ' + str(base_artist[x]))
        counter = 1
        
        for y in range(total_pages):
            artist_url = "https://api.songkick.com/api/3.0/artists/"+str(base_artist_2)+"/gigography.json?apikey="+"ORhDmrgUGkhdnXgP"+"&page="+(str(y+1))
            artist_json = requests.get(artist_url).json()
            for x in artist_json['resultsPage']['results']['event']:
                if str(x['location']['city']).split(",")[-1].strip() == "US":
                    event_number.append(counter)
                    event_name.append(str(x['displayName']))
                    popularity.append(str(x['popularity']))
                    location.append(str(x['venue']['displayName']))
                    longitude.append(str(x['venue']['lat']))
                    latitude.append(str(x['venue']['lng']))
                    city.append(str(x['location']['city']))
                    start_date.append(str(x['start']['date']))
                    start_time.append(str(x['start']['time']))
                    counter += 1
    artist_pd = pd.DataFrame({
        "Event Number": event_number,
        "Event Name": event_name,
        "Popularity": popularity,
        "Venue": location,
        "Longitude": longitude,
        "Latitude": latitude,
        "City": city,
        "Start Date": start_date,
        "Start Time": start_time
    })
    indexed_pd = artist_pd.set_index("Event Number")
    indexed_pd.to_csv(artist_code + "_events.csv")
    pd_json = json.loads(indexed_pd.reset_index().to_json(orient='records'))
    return pd_json

# %%
dream_events = concert_info(artist_code("Dream Theater"))
bruno_events = concert_info(artist_code("Bruno Mars"))
garth_events = concert_info(artist_code("Garth Brooks"))
eminem_events = concert_info(artist_code("Eminem"))
radiohead_events = concert_info(artist_code("Radiohead"))
beyonce_events = concert_info(artist_code("Beyonce"))
kanye_events = concert_info(artist_code("Kanye West"))
mana_events = concert_info(artist_code("Mana"))
odesza_events = concert_info(artist_code("Odesza"))
jcole_events = concert_info(artist_code("J Cole"))
mayer_events = concert_info(artist_code("John Mayer"))
russ_events = concert_info(artist_code("Russ"))
sza_events = concert_info(artist_code("SZA"))
trippie_events = concert_info(artist_code("Trippie Redd"))
# Out:
# PRINTING EVENTS FOR ARTIST: 8765
# PRINTING EVENTS FOR ARTIST: 941964
# PRINTING EVENTS FOR ARTIST: 283090
# PRINTING EVENTS FOR ARTIST: 182968
# PRINTING EVENTS FOR ARTIST: 253846
# PRINTING EVENTS FOR ARTIST: 553938
# PRINTING EVENTS FOR ARTIST: 552177
# PRINTING EVENTS FOR ARTIST: 106220
# PRINTING EVENTS FOR ARTIST: 6018139
# PRINTING EVENTS FOR ARTIST: 832745
# PRINTING EVENTS FOR ARTIST: 442137
# PRINTING EVENTS FOR ARTIST: 407566
# PRINTING EVENTS FOR ARTIST: 3352181
# PRINTING EVENTS FOR ARTIST: 9212594

# %%
sza_events
# Out:
# [{'City': 'New York, NY, US',
#   'Event Name': 'Misun, Cheers Elephant, SZA, Bianca Raquel, and 1 more… at Drom (October 16, 2012)',
#   'Event Number': 1,
#   'Latitude': '-73.9841494',
#   'Longitude': '40.7252014',
#   'Popularity': '0.006355',
#   'Start Date': '2012-10-16',
#   'Start Time': '21:00:00',
#   'Venue': 'Drom'},
#  {'City': 'Manhattan, NY, US',
#   'Event Name': "Raw with Iman Omari, Rachel Brown, SZA, and 1 more… at S.O.B.'s (January 9, 2013)",
#   'Event Number': 2,
#   'Latitude': '-74.0051241',
#   'Longitude': '40.7284492',
#   'Popularity': '0.086669',
#   'Start Date': '2013-01-09',
#   'Start Time': '21:00:00',
#   'Venue': "S.O.B.'s"},
#  {'City': 'Brooklyn, NY, US',
#   'Event Name': 'Chad Valley with Rush Midnight, SZA, and Letting Up Despite Great Faults at Glasslands Gallery (April 12, 2013)',
#   'Event Number': 3,
#   'Latitude': '-73.9664821',
#   'Longitude': '40.715135',
#   'Popularity': '0.104766',
#   'Start Date': '2013-04-12',
#   'Start Time': '20:30:00',
#   'Venue': 'Glasslands Gallery'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'SZA with Child Actor, Ydimitu, and Young Magic at Pianos (April 13, 2013)',
#   'Event Number': 4,
#   'Latitude': '-73.9878164',
#   'Longitude': '40.7211268',
#   'Popularity': '0.00728',
#   'Start Date': '2013-04-13',
#   'Start Time': '20:00:00',
#   'Venue': 'Pianos'},
#  {'City': 'Washington, DC, US',
#   'Event Name': 'Broccoli City Festival 2013',
#   'Event Number': 5,
#   'Latitude': '-77.0074739',
#   'Longitude': '38.8746482',
#   'Popularity': '0.085316',
#   'Start Date': '2013-04-21',
#   'Start Time': 'None',
#   'Venue': 'Fairgrounds'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Phoenix with SZA at Boulevard Pool, The Cosmopolitan of Las Vegas (October 8, 2013)',
#   'Event Number': 6,
#   'Latitude': '-115.1732124',
#   'Longitude': '36.109622',
#   'Popularity': '0.293133',
#   'Start Date': '2013-10-08',
#   'Start Time': '21:00:00',
#   'Venue': 'Boulevard Pool, The Cosmopolitan of Las Vegas'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Little Dragon with SZA at El Rey Theatre (October 17, 2013)',
#   'Event Number': 7,
#   'Latitude': '-118.3487992',
#   'Longitude': '34.062397',
#   'Popularity': '0.114401',
#   'Start Date': '2013-10-17',
#   'Start Time': '20:00:00',
#   'Venue': 'El Rey Theatre'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Travis Scott, SZA, and Calvin Love with Saul Williams and 6 more… at Eventi Hotel (October 19, 2013)',
#   'Event Number': 8,
#   'Latitude': '-73.9898959',
#   'Longitude': '40.7472165',
#   'Popularity': '0.029191',
#   'Start Date': '2013-10-19',
#   'Start Time': '13:00:00',
#   'Venue': 'Eventi Hotel'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Little Dragon with SZA at The Bowery Ballroom (October 23, 2013)',
#   'Event Number': 9,
#   'Latitude': '-73.9935389',
#   'Longitude': '40.7203623',
#   'Popularity': '0.114401',
#   'Start Date': '2013-10-23',
#   'Start Time': '20:00:00',
#   'Venue': 'The Bowery Ballroom'},
#  {'City': 'Brooklyn, NY, US',
#   'Event Name': 'Little Dragon and SZA at Music Hall of Williamsburg (October 24, 2013)',
#   'Event Number': 10,
#   'Latitude': '-73.9617103',
#   'Longitude': '40.7192832',
#   'Popularity': '0.114401',
#   'Start Date': '2013-10-24',
#   'Start Time': '20:00:00',
#   'Venue': 'Music Hall of Williamsburg'},
#  {'City': 'San Antonio, TX, US',
#   'Event Name': 'The Psychedelic Furs, Phantogram, The Joy Formidable, Twin Shadow, and 6 more… at Villita Assembly Building (March 21, 2014)',
#   'Event Number': 11,
#   'Latitude': '-98.4893001',
#   'Longitude': '29.4218758',
#   'Popularity': '0.139154',
#   'Start Date': '2014-03-21',
#   'Start Time': '18:00:00',
#   'Venue': 'Villita Assembly Building'},
#  {'City': 'San Antonio, TX, US',
#   'Event Name': 'Phantogram, The Psychedelic Furs, Washed Out, Twin Shadow, and 10 more… at Villita Assembly Building (March 22, 2014)',
#   'Event Number': 12,
#   'Latitude': '-98.4893001',
#   'Longitude': '29.4218758',
#   'Popularity': '0.139154',
#   'Start Date': '2014-03-22',
#   'Start Time': '16:30:00',
#   'Venue': 'Villita Assembly Building'},
#  {'City': 'New Orleans, LA, US',
#   'Event Name': 'Common with MC Lyte, SZA, and DJ Jermaine at House of Blues (July 5, 2014)',
#   'Event Number': 13,
#   'Latitude': '-90.0661661',
#   'Longitude': '29.9531604',
#   'Popularity': '0.161109',
#   'Start Date': '2014-07-05',
#   'Start Time': '13:00:00',
#   'Venue': 'House of Blues'},
#  {'City': 'Saugerties, NY, US',
#   'Event Name': 'The Hudson Project 2014',
#   'Event Number': 14,
#   'Latitude': '-73.98827',
#   'Longitude': '42.08764',
#   'Popularity': '0.581923',
#   'Start Date': '2014-07-11',
#   'Start Time': '00:00:00',
#   'Venue': 'Winston Farm'},
#  {'City': 'Brooklyn, NY, US',
#   'Event Name': 'SZA with Cakes Da Killa, Denitia & Sene, Princess Nokia, and 1 more… at Rough Trade NYC (July 15, 2014)',
#   'Event Number': 15,
#   'Latitude': '-73.9598502',
#   'Longitude': '40.7209863',
#   'Popularity': '0.037003',
#   'Start Date': '2014-07-15',
#   'Start Time': '20:00:00',
#   'Venue': 'Rough Trade NYC'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'Pitchfork Music Festival 2014',
#   'Event Number': 16,
#   'Latitude': '-87.6660887',
#   'Longitude': '41.8851191',
#   'Popularity': '0.553525',
#   'Start Date': '2014-07-18',
#   'Start Time': '15:00:00',
#   'Venue': 'Union Park'},
#  {'City': 'Washington, DC, US',
#   'Event Name': 'Trillectro Music Festival 2014',
#   'Event Number': 17,
#   'Latitude': '-76.97279',
#   'Longitude': '38.889563',
#   'Popularity': '0.385214',
#   'Start Date': '2014-08-23',
#   'Start Time': 'None',
#   'Venue': 'RFK Stadium'},
#  {'City': 'Brooklyn, NY, US',
#   'Event Name': 'AFROPUNK Festival 2014',
#   'Event Number': 18,
#   'Latitude': '-73.9830896',
#   'Longitude': '40.6984282',
#   'Popularity': '0.069593',
#   'Start Date': '2014-08-23',
#   'Start Time': 'None',
#   'Venue': 'Commodore Barry Park'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Made in America Festival 2014',
#   'Event Number': 19,
#   'Latitude': '-118.24282',
#   'Longitude': '34.0547',
#   'Popularity': '0.739801',
#   'Start Date': '2014-08-30',
#   'Start Time': '12:00:00',
#   'Venue': 'Grand Park'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'P.O.S, SZA, Poliça (DJ Set), Le1f, and 5 more… at Fine Line Music Cafe (September 13, 2014)',
#   'Event Number': 20,
#   'Latitude': '-93.27249',
#   'Longitude': '44.98139',
#   'Popularity': '0.122995',
#   'Start Date': '2014-09-13',
#   'Start Time': '04:00:00',
#   'Venue': 'Fine Line Music Cafe'},
#  {'City': 'Portland, OR, US',
#   'Event Name': 'Shaprece and SZA with Magic Fades at Holocene (October 7, 2014)',
#   'Event Number': 21,
#   'Latitude': '-122.6553277',
#   'Longitude': '45.5175739',
#   'Popularity': '0.031564',
#   'Start Date': '2014-10-07',
#   'Start Time': '20:00:00',
#   'Venue': 'Holocene'},
#  {'City': 'Lawrence, KS, US',
#   'Event Name': 'SZA at Liberty Hall (November 6, 2014)',
#   'Event Number': 22,
#   'Latitude': '-95.2356564',
#   'Longitude': '38.9714784',
#   'Popularity': '0.013403',
#   'Start Date': '2014-11-06',
#   'Start Time': '21:00:00',
#   'Venue': 'Liberty Hall'},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'FUN FUN FUN FEST 2014',
#   'Event Number': 23,
#   'Latitude': '-97.74962',
#   'Longitude': '30.26035',
#   'Popularity': '0.557685',
#   'Start Date': '2014-11-07',
#   'Start Time': '13:00:00',
#   'Venue': 'Auditorium Shores'},
#  {'City': 'Silver Spring, MD, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at The Fillmore Silver Spring (December 2, 2014)',
#   'Event Number': 24,
#   'Latitude': '-77.027928',
#   'Longitude': '38.997482',
#   'Popularity': '0.105426',
#   'Start Date': '2014-12-02',
#   'Start Time': '19:00:00',
#   'Venue': 'The Fillmore Silver Spring'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at PlayStation Theater (December 3, 2014)',
#   'Event Number': 25,
#   'Latitude': '-73.9861364',
#   'Longitude': '40.7576068',
#   'Popularity': '0.062922',
#   'Start Date': '2014-12-03',
#   'Start Time': 'None',
#   'Venue': 'PlayStation Theater'},
#  {'City': 'Baltimore, MD, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at Baltimore Soundstage (December 4, 2014)',
#   'Event Number': 26,
#   'Latitude': '-76.6068397',
#   'Longitude': '39.2876066',
#   'Popularity': '0.057472',
#   'Start Date': '2014-12-04',
#   'Start Time': '19:00:00',
#   'Venue': 'Baltimore Soundstage'},
#  {'City': 'Philadelphia, PA, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at Electric Factory (December 5, 2014)',
#   'Event Number': 27,
#   'Latitude': '-75.1502809',
#   'Longitude': '39.9589847',
#   'Popularity': '0.063267',
#   'Start Date': '2014-12-05',
#   'Start Time': '20:30:00',
#   'Venue': 'Electric Factory'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at The Novo by Microsoft (December 7, 2014)',
#   'Event Number': 28,
#   'Latitude': '-118.2654979',
#   'Longitude': '34.0449376',
#   'Popularity': '0.098487',
#   'Start Date': '2014-12-07',
#   'Start Time': 'None',
#   'Venue': 'The Novo by Microsoft'},
#  {'City': 'Sacramento, CA, US',
#   'Event Name': "SZA with J.sirus at Harlow's (December 8, 2014)",
#   'Event Number': 29,
#   'Latitude': '-121.4701755',
#   'Longitude': '38.5739832',
#   'Popularity': '0.007751',
#   'Start Date': '2014-12-08',
#   'Start Time': '20:00:00',
#   'Venue': "Harlow's"},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at The Warfield (December 10, 2014)',
#   'Event Number': 30,
#   'Latitude': '-122.4101811',
#   'Longitude': '37.7826598',
#   'Popularity': '0.057472',
#   'Start Date': '2014-12-10',
#   'Start Time': 'None',
#   'Venue': 'The Warfield'},
#  {'City': 'Santa Ana, CA, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at The Observatory (December 11, 2014)',
#   'Event Number': 31,
#   'Latitude': '-117.9194457',
#   'Longitude': '33.6998449',
#   'Popularity': '0.057472',
#   'Start Date': '2014-12-11',
#   'Start Time': '20:00:00',
#   'Venue': 'The Observatory'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at The Novo by Microsoft (December 12, 2014)',
#   'Event Number': 32,
#   'Latitude': '-118.2654979',
#   'Longitude': '34.0449376',
#   'Popularity': '0.098487',
#   'Start Date': '2014-12-12',
#   'Start Time': '20:00:00',
#   'Venue': 'The Novo by Microsoft'},
#  {'City': 'Phoenix, AZ, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at Celebrity Theatre (December 13, 2014)',
#   'Event Number': 33,
#   'Latitude': '-112.0145748',
#   'Longitude': '33.4544202',
#   'Popularity': '0.057472',
#   'Start Date': '2014-12-13',
#   'Start Time': '21:00:00',
#   'Venue': 'Celebrity Theatre'},
#  {'City': 'Royal Oak, MI, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at Royal Oak Music Theatre (December 19, 2014)',
#   'Event Number': 34,
#   'Latitude': '-83.1474339',
#   'Longitude': '42.4873251',
#   'Popularity': '0.057472',
#   'Start Date': '2014-12-19',
#   'Start Time': 'None',
#   'Venue': 'Royal Oak Music Theatre'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at House of Blues (December 20, 2014)',
#   'Event Number': 35,
#   'Latitude': '-87.6292039',
#   'Longitude': '41.8882037',
#   'Popularity': '0.134085',
#   'Start Date': '2014-12-20',
#   'Start Time': 'None',
#   'Venue': 'House of Blues'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'Jhené Aiko with SZA and The Internet at Skyway Theatre (December 21, 2014)',
#   'Event Number': 36,
#   'Latitude': '-93.274927',
#   'Longitude': '44.977412',
#   'Popularity': '0.057472',
#   'Start Date': '2014-12-21',
#   'Start Time': 'None',
#   'Venue': 'Skyway Theatre'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'SZA at Center Stage Theater (January 17, 2015)',
#   'Event Number': 37,
#   'Latitude': '-84.3880007',
#   'Longitude': '33.7920851',
#   'Popularity': '0.017675',
#   'Start Date': '2015-01-17',
#   'Start Time': '20:00:00',
#   'Venue': 'Center Stage Theater'},
#  {'City': 'Columbia, MD, US',
#   'Event Name': 'Sweetlife Festival 2015',
#   'Event Number': 38,
#   'Latitude': '-76.86278',
#   'Longitude': '39.20877',
#   'Popularity': '0.638306',
#   'Start Date': '2015-05-30',
#   'Start Time': '12:00:00',
#   'Venue': 'Merriweather Post Pavilion'},
#  {'City': 'Manchester, TN, US',
#   'Event Name': 'Bonnaroo Music & Arts Festival 2015',
#   'Event Number': 39,
#   'Latitude': '-86.04642',
#   'Longitude': '35.47811',
#   'Popularity': '0.583188',
#   'Start Date': '2015-06-11',
#   'Start Time': '12:00:00',
#   'Venue': 'Great Stage Park'},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'SZA with Tut at South Side Music Hall (July 11, 2015)',
#   'Event Number': 40,
#   'Latitude': '-96.797987',
#   'Longitude': '32.768777',
#   'Popularity': '0.017214',
#   'Start Date': '2015-07-11',
#   'Start Time': '19:11:00',
#   'Venue': 'South Side Music Hall'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': "SZA with Gabriel Garzón-Montano and Montano at Reggie's Rock Club (July 31, 2015)",
#   'Event Number': 41,
#   'Latitude': '-87.6269514',
#   'Longitude': '41.8540522',
#   'Popularity': '0.062026',
#   'Start Date': '2015-07-31',
#   'Start Time': '22:00:00',
#   'Venue': "Reggie's Rock Club"},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'Outside Lands Music & Arts Festival 2015',
#   'Event Number': 42,
#   'Latitude': '-122.46371',
#   'Longitude': '37.78229',
#   'Popularity': '0.581923',
#   'Start Date': '2015-08-07',
#   'Start Time': '12:00:00',
#   'Venue': 'Golden Gate Park'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'Ms. Lauryn Hill, A$AP Rocky, Wale, Janelle Monáe, and 5 more… at Cellairis Amphitheatre at Lakewood (September 12, 2015)',
#   'Event Number': 43,
#   'Latitude': '-84.3961',
#   'Longitude': '33.70427',
#   'Popularity': '0.37371',
#   'Start Date': '2015-09-12',
#   'Start Time': '12:00:00',
#   'Venue': 'Cellairis Amphitheatre at Lakewood'},
#  {'City': 'Madison, WI, US',
#   'Event Name': 'SZA and Lizzo at Majestic Theatre (September 15, 2015)',
#   'Event Number': 44,
#   'Latitude': '-89.3807714',
#   'Longitude': '43.074528',
#   'Popularity': '0.018846',
#   'Start Date': '2015-09-15',
#   'Start Time': 'None',
#   'Venue': 'Majestic Theatre'},
#  {'City': 'Champaign, IL, US',
#   'Event Name': 'SZA and Lizzo at High Dive (September 16, 2015)',
#   'Event Number': 45,
#   'Latitude': '-88.2408818',
#   'Longitude': '40.1177536',
#   'Popularity': '0.01952',
#   'Start Date': '2015-09-16',
#   'Start Time': 'None',
#   'Venue': 'High Dive'},
#  {'City': 'Bloomington, IN, US',
#   'Event Name': "SZA and Lizzo at Kilroy's Recess (September 17, 2015)",
#   'Event Number': 46,
#   'Latitude': '-86.528507',
#   'Longitude': '39.166247',
#   'Popularity': '0.063008',
#   'Start Date': '2015-09-17',
#   'Start Time': 'None',
#   'Venue': "Kilroy's Recess"},
#  {'City': 'Lansing, MI, US',
#   'Event Name': 'SZA and Lizzo at The Loft (September 19, 2015)',
#   'Event Number': 47,
#   'Latitude': '-84.547514',
#   'Longitude': '42.7334153',
#   'Popularity': '0.018846',
#   'Start Date': '2015-09-19',
#   'Start Time': 'None',
#   'Venue': 'The Loft'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Life is Beautiful Festival 2015',
#   'Event Number': 48,
#   'Latitude': '-115.14006',
#   'Longitude': '36.16917',
#   'Popularity': '0.599864',
#   'Start Date': '2015-09-25',
#   'Start Time': '15:00:02',
#   'Venue': 'Downtown Las Vegas'},
#  {'City': 'Portland, OR, US',
#   'Event Name': 'SZA with Risky Star and Joyya Marie at Wonder Ballroom (April 13, 2016)',
#   'Event Number': 49,
#   'Latitude': '-122.6634854',
#   'Longitude': '45.5408474',
#   'Popularity': '0.022767',
#   'Start Date': '2016-04-13',
#   'Start Time': '21:00:00',
#   'Venue': 'Wonder Ballroom'},
#  {'City': 'Indio, CA, US',
#   'Event Name': 'Coachella (Weekend 1) 2016',
#   'Event Number': 50,
#   'Latitude': '-116.23892',
#   'Longitude': '33.68233',
#   'Popularity': '0.639334',
#   'Start Date': '2016-04-15',
#   'Start Time': 'None',
#   'Venue': 'Empire Polo Club'},
#  {'City': 'Indio, CA, US',
#   'Event Name': 'Coachella (Weekend 2) 2016',
#   'Event Number': 51,
#   'Latitude': '-116.23892',
#   'Longitude': '33.68233',
#   'Popularity': '0.639334',
#   'Start Date': '2016-04-22',
#   'Start Time': 'None',
#   'Venue': 'Empire Polo Club'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Panorama Festival 2016',
#   'Event Number': 52,
#   'Latitude': '-73.92567',
#   'Longitude': '40.78377',
#   'Popularity': '0.58421',
#   'Start Date': '2016-07-22',
#   'Start Time': '20:00:00',
#   'Venue': "Randall's Island"},
#  {'City': 'Philadelphia, PA, US',
#   'Event Name': 'Made in America Festival 2016',
#   'Event Number': 53,
#   'Latitude': '-75.17355',
#   'Longitude': '39.96021',
#   'Popularity': '1.0',
#   'Start Date': '2016-09-03',
#   'Start Time': '12:00:00',
#   'Venue': 'Benjamin Franklin Parkway'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Camp Flog Gnaw Carnival 2016',
#   'Event Number': 54,
#   'Latitude': '-118.28456',
#   'Longitude': '34.0126',
#   'Popularity': '0.647064',
#   'Start Date': '2016-11-12',
#   'Start Time': 'None',
#   'Venue': 'Exposition Park'},
#  {'City': 'New Haven, CT, US',
#   'Event Name': "SZA with Smino and Ravyn Lenae at Toad's Place (August 18, 2017)",
#   'Event Number': 55,
#   'Latitude': '-72.92936',
#   'Longitude': '41.31157',
#   'Popularity': '0.124348',
#   'Start Date': '2017-08-18',
#   'Start Time': 'None',
#   'Venue': "Toad's Place"},
#  {'City': 'Providence, RI, US',
#   'Event Name': 'Ravyn Lenae, SZA, and Smino at Fête Music Hall (August 20, 2017)',
#   'Event Number': 56,
#   'Latitude': '-71.44338',
#   'Longitude': '41.81602',
#   'Popularity': '0.124348',
#   'Start Date': '2017-08-20',
#   'Start Time': '19:00:00',
#   'Venue': 'Fête Music Hall'},
#  {'City': 'Richmond, VA, US',
#   'Event Name': 'SZA with Smino and Rayvn Lenae at The National (August 21, 2017)',
#   'Event Number': 57,
#   'Latitude': '-77.4353949',
#   'Longitude': '37.5417961',
#   'Popularity': '0.100742',
#   'Start Date': '2017-08-21',
#   'Start Time': '19:00:00',
#   'Venue': 'The National'},
#  {'City': 'Boston, MA, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at Royale (August 25, 2017)',
#   'Event Number': 58,
#   'Latitude': '-71.06523',
#   'Longitude': '42.35003',
#   'Popularity': '0.124348',
#   'Start Date': '2017-08-25',
#   'Start Time': '18:00:00',
#   'Venue': 'Royale'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'AFROPUNK Festival 2017',
#   'Event Number': 59,
#   'Latitude': '-74.00594',
#   'Longitude': '40.71278',
#   'Popularity': '0.124348',
#   'Start Date': '2017-08-26',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'Detroit, MI, US',
#   'Event Name': 'Smino, Ravyn Lenae, and SZA at The Fillmore Detroit (August 30, 2017)',
#   'Event Number': 60,
#   'Latitude': '-83.05152',
#   'Longitude': '42.3378',
#   'Popularity': '0.124348',
#   'Start Date': '2017-08-30',
#   'Start Time': '19:00:00',
#   'Venue': 'The Fillmore Detroit'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'SZA with Ravyn Lenae and Smino at Concord Music Hall (August 31, 2017)',
#   'Event Number': 61,
#   'Latitude': '-87.69003',
#   'Longitude': '41.91856',
#   'Popularity': '0.124348',
#   'Start Date': '2017-08-31',
#   'Start Time': '18:00:00',
#   'Venue': 'Concord Music Hall'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'SZA and Protohype with Smino at Cabooze (September 1, 2017)',
#   'Event Number': 62,
#   'Latitude': '-93.246801',
#   'Longitude': '44.963384',
#   'Popularity': '0.100742',
#   'Start Date': '2017-09-01',
#   'Start Time': '20:00:00',
#   'Venue': 'Cabooze'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at First Avenue Mainroom (September 1, 2017)',
#   'Event Number': 63,
#   'Latitude': '-93.27608',
#   'Longitude': '44.97827',
#   'Popularity': '0.125102',
#   'Start Date': '2017-09-01',
#   'Start Time': '18:00:00',
#   'Venue': 'First Avenue Mainroom'},
#  {'City': 'Lawrence, KS, US',
#   'Event Name': 'SZA at Granada Theatre (September 3, 2017)',
#   'Event Number': 64,
#   'Latitude': '-95.2358532',
#   'Longitude': '38.9647957',
#   'Popularity': '0.046551',
#   'Start Date': '2017-09-03',
#   'Start Time': '20:00:00',
#   'Venue': 'Granada Theatre'},
#  {'City': 'Kansas City, MO, US',
#   'Event Name': 'Ravyn Lenae, Smino, and SZA at Uptown Theater (September 3, 2017)',
#   'Event Number': 65,
#   'Latitude': '-94.59053',
#   'Longitude': '39.06115',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-03',
#   'Start Time': '20:00:00',
#   'Venue': 'Uptown Theater'},
#  {'City': 'Lincoln, NE, US',
#   'Event Name': 'SZA at Bourbon Theatre (September 5, 2017)',
#   'Event Number': 66,
#   'Latitude': '-96.700617',
#   'Longitude': '40.813249',
#   'Popularity': '0.046784',
#   'Start Date': '2017-09-05',
#   'Start Time': '20:00:00',
#   'Venue': 'Bourbon Theatre'},
#  {'City': 'Englewood, CO, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at Gothic Theatre (September 6, 2017)',
#   'Event Number': 67,
#   'Latitude': '-104.98802',
#   'Longitude': '39.65763',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-06',
#   'Start Time': '19:00:00',
#   'Venue': 'Gothic Theatre'},
#  {'City': 'Anaheim, CA, US',
#   'Event Name': 'Day n Night Festival 2017',
#   'Event Number': 68,
#   'Latitude': '-117.883043',
#   'Longitude': '33.80003',
#   'Popularity': '0.569913',
#   'Start Date': '2017-09-08',
#   'Start Time': '12:00:00',
#   'Venue': 'Angel Stadium of Anaheim'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'SZA with Ravyn Lenae at Vinyl, Hard Rock Hotel & Casino (September 8, 2017)',
#   'Event Number': 69,
#   'Latitude': '-115.15385',
#   'Longitude': '36.10901',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-08',
#   'Start Time': '19:00:00',
#   'Venue': 'Vinyl, Hard Rock Hotel & Casino'},
#  {'City': 'Sacramento, CA, US',
#   'Event Name': 'SZA at Ace of Spades (September 10, 2017)',
#   'Event Number': 70,
#   'Latitude': '-121.490972',
#   'Longitude': '38.5699036',
#   'Popularity': '0.047387',
#   'Start Date': '2017-09-10',
#   'Start Time': '19:00:00',
#   'Venue': 'Ace of Spades'},
#  {'City': 'Santa Cruz, CA, US',
#   'Event Name': 'SZA with Ravyn Lenae and Smino at The Catalyst (September 12, 2017)',
#   'Event Number': 71,
#   'Latitude': '-122.02554',
#   'Longitude': '36.97137',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-12',
#   'Start Time': '21:00:00',
#   'Venue': 'The Catalyst'},
#  {'City': 'Eugene, OR, US',
#   'Event Name': 'Ravyn Lenae, SZA, and Smino at WOW Hall (September 13, 2017)',
#   'Event Number': 72,
#   'Latitude': '-123.09706',
#   'Longitude': '44.05121',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-13',
#   'Start Time': '21:00:00',
#   'Venue': 'WOW Hall'},
#  {'City': 'Portland, OR, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at Roseland Theater (September 16, 2017)',
#   'Event Number': 73,
#   'Latitude': '-122.67644',
#   'Longitude': '45.52331',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-16',
#   'Start Time': 'None',
#   'Venue': 'Roseland Theater'},
#  {'City': 'Seattle, WA, US',
#   'Event Name': 'Smino, Ravyn Lenae, and SZA at Neptune Theatre (September 17, 2017)',
#   'Event Number': 74,
#   'Latitude': '-122.31365',
#   'Longitude': '47.66128',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-17',
#   'Start Time': '20:00:00',
#   'Venue': 'Neptune Theatre'},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at The Regency Ballroom (September 19, 2017)',
#   'Event Number': 75,
#   'Latitude': '-122.42143',
#   'Longitude': '37.78787',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-19',
#   'Start Time': '19:00:00',
#   'Venue': 'The Regency Ballroom'},
#  {'City': 'Tempe, AZ, US',
#   'Event Name': 'SZA and Ravyn Lenae at Marquee Theatre (September 21, 2017)',
#   'Event Number': 76,
#   'Latitude': '-111.94373',
#   'Longitude': '33.43689',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-21',
#   'Start Time': '18:30:00',
#   'Venue': 'Marquee Theatre'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at The Novo by Microsoft (September 25, 2017)',
#   'Event Number': 77,
#   'Latitude': '-118.2655',
#   'Longitude': '34.04494',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-25',
#   'Start Time': '19:00:00',
#   'Venue': 'The Novo by Microsoft'},
#  {'City': 'New Orleans, LA, US',
#   'Event Name': 'Ravyn Lenae and SZA at House of Blues (September 28, 2017)',
#   'Event Number': 78,
#   'Latitude': '-90.06617',
#   'Longitude': '29.95316',
#   'Popularity': '0.124348',
#   'Start Date': '2017-09-28',
#   'Start Time': '19:00:00',
#   'Venue': 'House of Blues'},
#  {'City': 'Austin, TX, US',
#   'Event Name': "SZA with Smino and Ravyn Lenae at Emo's Austin (October 1, 2017)",
#   'Event Number': 79,
#   'Latitude': '-97.7282',
#   'Longitude': '30.2404',
#   'Popularity': '0.124348',
#   'Start Date': '2017-10-01',
#   'Start Time': '19:00:00',
#   'Venue': "Emo's Austin"},
#  {'City': 'Houston, TX, US',
#   'Event Name': 'SZA, Smino, and Ravyn Lanae at Warehouse Live (October 3, 2017)',
#   'Event Number': 80,
#   'Latitude': '-95.3546736',
#   'Longitude': '29.7521221',
#   'Popularity': '0.100742',
#   'Start Date': '2017-10-03',
#   'Start Time': 'None',
#   'Venue': 'Warehouse Live'},
#  {'City': 'Nashville, TN, US',
#   'Event Name': 'Commodore Quake, SZA, and Migos at Memorial Gymnasium, Vanderbilt University (October 5, 2017)',
#   'Event Number': 81,
#   'Latitude': '-86.8067804',
#   'Longitude': '36.1448738',
#   'Popularity': '0.129004',
#   'Start Date': '2017-10-05',
#   'Start Time': '20:00:00',
#   'Venue': 'Memorial Gymnasium, Vanderbilt University'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'SZA with Ravyn Lenae at The Ground (October 7, 2017)',
#   'Event Number': 82,
#   'Latitude': '-80.19314',
#   'Longitude': '25.78448',
#   'Popularity': '0.124348',
#   'Start Date': '2017-10-07',
#   'Start Time': '21:00:00',
#   'Venue': 'The Ground'},
#  {'City': 'Ybor City, FL, US',
#   'Event Name': 'SZA at Orpheum (October 8, 2017)',
#   'Event Number': 83,
#   'Latitude': '-82.437391',
#   'Longitude': '27.960041',
#   'Popularity': '0.051856',
#   'Start Date': '2017-10-08',
#   'Start Time': '19:00:00',
#   'Venue': 'Orpheum'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'Smino, Ravyn Lenae, and SZA at The Tabernacle (October 9, 2017)',
#   'Event Number': 84,
#   'Latitude': '-84.39146',
#   'Longitude': '33.7587',
#   'Popularity': '0.124348',
#   'Start Date': '2017-10-09',
#   'Start Time': '20:00:00',
#   'Venue': 'The Tabernacle'},
#  {'City': 'Greensboro, NC, US',
#   'Event Name': 'SZA at Cone Denim Entertainment Center (October 11, 2017)',
#   'Event Number': 85,
#   'Latitude': '-79.789924',
#   'Longitude': '36.071838',
#   'Popularity': '0.052262',
#   'Start Date': '2017-10-11',
#   'Start Time': '20:00:00',
#   'Venue': 'Cone Denim Entertainment Center'},
#  {'City': 'Charlotte, NC, US',
#   'Event Name': 'Smino, Ravyn Lenae, and SZA at The Underground (October 12, 2017)',
#   'Event Number': 86,
#   'Latitude': '-80.84531',
#   'Longitude': '35.2403',
#   'Popularity': '0.124348',
#   'Start Date': '2017-10-12',
#   'Start Time': '20:00:00',
#   'Venue': 'The Underground'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'SZA at The Novo by Microsoft (November 14, 2017)',
#   'Event Number': 87,
#   'Latitude': '-118.2654979',
#   'Longitude': '34.0449376',
#   'Popularity': '0.057042',
#   'Start Date': '2017-11-14',
#   'Start Time': '19:00:00',
#   'Venue': 'The Novo by Microsoft'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'SZA, Post Malone, Ty Dolla $ign, and Cheat Codes at Pier 36 (December 5, 2017)',
#   'Event Number': 88,
#   'Latitude': '-73.98518',
#   'Longitude': '40.71063',
#   'Popularity': '0.224573',
#   'Start Date': '2017-12-05',
#   'Start Time': 'None',
#   'Venue': 'Pier 36'},
#  {'City': 'Brooklyn, NY, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at Brooklyn Steel (December 10, 2017)',
#   'Event Number': 89,
#   'Latitude': '-73.93878',
#   'Longitude': '40.71936',
#   'Popularity': '0.124348',
#   'Start Date': '2017-12-10',
#   'Start Time': '19:00:00',
#   'Venue': 'Brooklyn Steel'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'SZA with Smino and Ravyn Lenae at Irving Plaza (December 11, 2017)',
#   'Event Number': 90,
#   'Latitude': '-73.98845',
#   'Longitude': '40.73492',
#   'Popularity': '0.124348',
#   'Start Date': '2017-12-11',
#   'Start Time': '19:00:00',
#   'Venue': 'Irving Plaza'},
#  {'City': 'Cleveland, OH, US',
#   'Event Name': 'Smino, Ravyn Lenae, and SZA at House of Blues (December 13, 2017)',
#   'Event Number': 91,
#   'Latitude': '-81.69086',
#   'Longitude': '41.49982',
#   'Popularity': '0.124348',
#   'Start Date': '2017-12-13',
#   'Start Time': '19:00:00',
#   'Venue': 'House of Blues'},
#  {'City': 'Indianapolis, IN, US',
#   'Event Name': 'Smino, Ravyn Lenae, and SZA at Egyptian Room, Old National Centre (December 15, 2017)',
#   'Event Number': 92,
#   'Latitude': '-86.1515',
#   'Longitude': '39.77465',
#   'Popularity': '0.124348',
#   'Start Date': '2017-12-15',
#   'Start Time': '19:30:00',
#   'Venue': 'Egyptian Room, Old National Centre'},
#  {'City': 'Louisville, KY, US',
#   'Event Name': 'Smino, Ravyn Lenae, and SZA at Mercury Ballroom (December 16, 2017)',
#   'Event Number': 93,
#   'Latitude': '-85.75794',
#   'Longitude': '38.24851',
#   'Popularity': '0.124348',
#   'Start Date': '2017-12-16',
#   'Start Time': '20:00:00',
#   'Venue': 'Mercury Ballroom'},
#  {'City': 'St Louis, MO, US',
#   'Event Name': 'SZA with Ravyn Lenae and Smino at The Ready Room (December 17, 2017)',
#   'Event Number': 94,
#   'Latitude': '-90.25381',
#   'Longitude': '38.62762',
#   'Popularity': '0.124348',
#   'Start Date': '2017-12-17',
#   'Start Time': '20:00:00',
#   'Venue': 'The Ready Room'},
#  {'City': 'St Louis, MO, US',
#   'Event Name': 'SZA at The Ready Room (December 19, 2017)',
#   'Event Number': 95,
#   'Latitude': '-90.253814',
#   'Longitude': '38.627618',
#   'Popularity': '0.063424',
#   'Start Date': '2017-12-19',
#   'Start Time': '20:00:00',
#   'Venue': 'The Ready Room'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'SZA at Concord Music Hall (December 20, 2017)',
#   'Event Number': 96,
#   'Latitude': '-87.6900284',
#   'Longitude': '41.9185623',
#   'Popularity': '0.063699',
#   'Start Date': '2017-12-20',
#   'Start Time': '18:00:00',
#   'Venue': 'Concord Music Hall'},
#  {'City': 'Philadelphia, PA, US',
#   'Event Name': 'Ravyn Lenae and SZA at Fillmore Philadelphia (December 22, 2017)',
#   'Event Number': 97,
#   'Latitude': '-75.13663',
#   'Longitude': '39.96609',
#   'Popularity': '0.124348',
#   'Start Date': '2017-12-22',
#   'Start Time': '20:00:00',
#   'Venue': 'Fillmore Philadelphia'},
#  {'City': 'Honolulu, HI, US',
#   'Event Name': 'SZA at The Republik (January 15, 2018)',
#   'Event Number': 98,
#   'Latitude': '-157.8448445',
#   'Longitude': '21.2941297',
#   'Popularity': '0.068998',
#   'Start Date': '2018-01-15',
#   'Start Time': '20:00:00',
#   'Venue': 'The Republik'},
#  {'City': 'Honolulu, HI, US',
#   'Event Name': 'SZA at The Republik (January 18, 2018)',
#   'Event Number': 99,
#   'Latitude': '-157.8448445',
#   'Longitude': '21.2941297',
#   'Popularity': '0.069875',
#   'Start Date': '2018-01-18',
#   'Start Time': '20:00:00',
#   'Venue': 'The Republik'},
#  {'City': 'Silver Spring, MD, US',
#   'Event Name': 'Smino and SZA at The Fillmore Silver Spring (February 5, 2018)',
#   'Event Number': 100,
#   'Latitude': '-77.027928',
#   'Longitude': '38.997482',
#   'Popularity': '0.100742',
#   'Start Date': '2018-02-05',
#   'Start Time': '20:00:00',
#   'Venue': 'The Fillmore Silver Spring'},
#  {'City': 'New Orleans, LA, US',
#   'Event Name': 'Buku Music and Art Project Festival 2018',
#   'Event Number': 101,
#   'Latitude': '-90.07153',
#   'Longitude': '29.95107',
#   'Popularity': '0.415981',
#   'Start Date': '2018-03-09',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'Indio, CA, US',
#   'Event Name': 'Coachella 2018',
#   'Event Number': 102,
#   'Latitude': '-116.23892',
#   'Longitude': '33.68233',
#   'Popularity': '0.894831',
#   'Start Date': '2018-04-13',
#   'Start Time': 'None',
#   'Venue': 'Empire Polo Club'},
#  {'City': 'Indio, CA, US',
#   'Event Name': 'Coachella 2018',
#   'Event Number': 103,
#   'Latitude': '-116.23892',
#   'Longitude': '33.68233',
#   'Popularity': '0.894831',
#   'Start Date': '2018-04-20',
#   'Start Time': 'None',
#   'Venue': 'Empire Polo Club'},
#  {'City': 'Syracuse, NY, US',
#   'Event Name': 'Gucci Mane and SZA at Carrier Dome, Syracuse University (April 27, 2018)',
#   'Event Number': 104,
#   'Latitude': '-76.1382483',
#   'Longitude': '43.0376369',
#   'Popularity': '0.186196',
#   'Start Date': '2018-04-27',
#   'Start Time': '19:20:00',
#   'Venue': 'Carrier Dome, Syracuse University'},
#  {'City': 'Auburn, WA, US',
#   'Event Name': 'Isaiah Rashad, Jay Rock, Sir, Ab-Soul, and 4 more… at White River Amphitheatre (May 5, 2018)',
#   'Event Number': 105,
#   'Latitude': '-122.1120309',
#   'Longitude': '47.2374581',
#   'Popularity': '0.550764',
#   'Start Date': '2018-05-05',
#   'Start Time': '19:30:00',
#   'Venue': 'White River Amphitheatre'},
#  {'City': 'Ridgefield, WA, US',
#   'Event Name': 'Isaiah Rashad, Sir, Ab-Soul, SZA, and 4 more… at Sunlight Supply Amphitheater (May 6, 2018)',
#   'Event Number': 106,
#   'Latitude': '-122.666113',
#   'Longitude': '45.746432',
#   'Popularity': '0.551031',
#   'Start Date': '2018-05-06',
#   'Start Time': '19:00:00',
#   'Venue': 'Sunlight Supply Amphitheater'},
#  {'City': 'Oakland, CA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Oracle Arena (May 8, 2018)',
#   'Event Number': 107,
#   'Latitude': '-122.2015715',
#   'Longitude': '37.7515541',
#   'Popularity': '0.55162',
#   'Start Date': '2018-05-08',
#   'Start Time': '19:30:00',
#   'Venue': 'Oracle Arena'},
#  {'City': 'Inglewood, CA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at The Forum (May 10, 2018)',
#   'Event Number': 108,
#   'Latitude': '-118.3405316',
#   'Longitude': '33.9582047',
#   'Popularity': '0.552375',
#   'Start Date': '2018-05-10',
#   'Start Time': '19:30:00',
#   'Venue': 'The Forum'},
#  {'City': 'Inglewood, CA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 2 more… at The Forum (May 11, 2018)',
#   'Event Number': 109,
#   'Latitude': '-118.3405316',
#   'Longitude': '33.9582047',
#   'Popularity': '0.210381',
#   'Start Date': '2018-05-11',
#   'Start Time': '19:30:00',
#   'Venue': 'The Forum'},
#  {'City': 'Oakland, CA, US',
#   'Event Name': 'Blurry Vision Festival 2018',
#   'Event Number': 110,
#   'Latitude': '-122.3223968',
#   'Longitude': '37.8063658',
#   'Popularity': '0.184238',
#   'Start Date': '2018-05-12',
#   'Start Time': 'None',
#   'Venue': 'Middle Harbor Shoreline Park'},
#  {'City': 'Chula Vista, CA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Mattress Firm Amphitheatre (May 13, 2018)',
#   'Event Number': 111,
#   'Latitude': '-117.0060564',
#   'Longitude': '32.5882959',
#   'Popularity': '0.553028',
#   'Start Date': '2018-05-13',
#   'Start Time': '19:30:00',
#   'Venue': 'Mattress Firm Amphitheatre'},
#  {'City': 'Phoenix, AZ, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Ak-Chin Pavilion (May 14, 2018)',
#   'Event Number': 112,
#   'Latitude': '-112.232875',
#   'Longitude': '33.470823',
#   'Popularity': '0.553269',
#   'Start Date': '2018-05-14',
#   'Start Time': '19:30:00',
#   'Venue': 'Ak-Chin Pavilion'},
#  {'City': 'Albuquerque, NM, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Isleta Amphitheater (May 15, 2018)',
#   'Event Number': 113,
#   'Latitude': '-106.63313',
#   'Longitude': '34.993524',
#   'Popularity': '0.553525',
#   'Start Date': '2018-05-15',
#   'Start Time': '19:30:00',
#   'Venue': 'Isleta Amphitheater'},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Starplex Pavilion (May 17, 2018)',
#   'Event Number': 114,
#   'Latitude': '-96.7534676',
#   'Longitude': '32.7756926',
#   'Popularity': '0.554159',
#   'Start Date': '2018-05-17',
#   'Start Time': '19:30:00',
#   'Venue': 'Starplex Pavilion'},
#  {'City': 'Gulf Shores, AL, US',
#   'Event Name': 'Hangout Festival 2018',
#   'Event Number': 115,
#   'Latitude': 'None',
#   'Longitude': 'None',
#   'Popularity': '0.614892',
#   'Start Date': '2018-05-18',
#   'Start Time': 'None',
#   'Venue': 'Gulf Shores Beach'},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Austin360 Amphitheater (May 18, 2018)',
#   'Event Number': 116,
#   'Latitude': '-97.6406811',
#   'Longitude': '30.13293',
#   'Popularity': '0.554384',
#   'Start Date': '2018-05-18',
#   'Start Time': '19:30:00',
#   'Venue': 'Austin360 Amphitheater'},
#  {'City': 'The Woodlands, TX, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Cynthia Woods Mitchell Pavilion (May 19, 2018)',
#   'Event Number': 117,
#   'Latitude': '-95.464029',
#   'Longitude': '30.161593',
#   'Popularity': '0.554607',
#   'Start Date': '2018-05-19',
#   'Start Time': '19:30:00',
#   'Venue': 'Cynthia Woods Mitchell Pavilion'},
#  {'City': 'Tampa, FL, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Midflorida Credit Union Amphitheatre (May 22, 2018)',
#   'Event Number': 118,
#   'Latitude': '-82.3588746',
#   'Longitude': '27.9896043',
#   'Popularity': '0.555412',
#   'Start Date': '2018-05-22',
#   'Start Time': '19:30:00',
#   'Venue': 'Midflorida Credit Union Amphitheatre'},
#  {'City': 'West Palm Beach, FL, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Coral Sky Amphitheatre at the South Florida Fairgrounds (May 23, 2018)',
#   'Event Number': 119,
#   'Latitude': '-80.186736',
#   'Longitude': '26.685477',
#   'Popularity': '0.55571',
#   'Start Date': '2018-05-23',
#   'Start Time': '19:30:00',
#   'Venue': 'Coral Sky Amphitheatre at the South Florida Fairgrounds'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'Jay Rock, Ab-Soul, SZA, ScHoolboy Q, and 2 more… at Cellairis Amphitheatre at Lakewood (May 25, 2018)',
#   'Event Number': 120,
#   'Latitude': '-84.396095',
#   'Longitude': '33.7042695',
#   'Popularity': '0.556298',
#   'Start Date': '2018-05-25',
#   'Start Time': '19:30:00',
#   'Venue': 'Cellairis Amphitheatre at Lakewood'},
#  {'City': 'Raleigh, NC, US',
#   'Event Name': 'Ab-Soul, ScHoolboy Q, Sir, SZA, and 3 more… at Coastal Credit Union Music Park at Walnut Creek (May 26, 2018)',
#   'Event Number': 121,
#   'Latitude': '-78.5763028',
#   'Longitude': '35.7493881',
#   'Popularity': '0.556538',
#   'Start Date': '2018-05-26',
#   'Start Time': '19:30:00',
#   'Venue': 'Coastal Credit Union Music Park at Walnut Creek'},
#  {'City': 'Virginia Beach, VA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Veterans United Home Loans Amphitheater (May 27, 2018)',
#   'Event Number': 122,
#   'Latitude': '-76.1019623',
#   'Longitude': '36.7686679',
#   'Popularity': '0.556748',
#   'Start Date': '2018-05-27',
#   'Start Time': '19:30:00',
#   'Venue': 'Veterans United Home Loans Amphitheater'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Madison Square Garden (May 29, 2018)',
#   'Event Number': 123,
#   'Latitude': '-73.991556',
#   'Longitude': '40.7497096',
#   'Popularity': '0.569659',
#   'Start Date': '2018-05-29',
#   'Start Time': '19:30:00',
#   'Venue': 'Madison Square Garden'},
#  {'City': 'Wantagh, NY, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Northwell Health at Jones Beach Theater (May 30, 2018)',
#   'Event Number': 124,
#   'Latitude': '-73.502518',
#   'Longitude': '40.6011406',
#   'Popularity': '0.557562',
#   'Start Date': '2018-05-30',
#   'Start Time': '19:30:00',
#   'Venue': 'Northwell Health at Jones Beach Theater'},
#  {'City': 'Bristow, VA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Jiffy Lube Live (June 1, 2018)',
#   'Event Number': 125,
#   'Latitude': '-77.587845',
#   'Longitude': '38.786011',
#   'Popularity': '0.558163',
#   'Start Date': '2018-06-01',
#   'Start Time': '19:30:00',
#   'Venue': 'Jiffy Lube Live'},
#  {'City': 'Hershey, PA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Hersheypark Stadium (June 2, 2018)',
#   'Event Number': 126,
#   'Latitude': '-76.6541182',
#   'Longitude': '40.2926999',
#   'Popularity': '0.55841',
#   'Start Date': '2018-06-02',
#   'Start Time': '19:30:00',
#   'Venue': 'Hersheypark Stadium'},
#  {'City': 'Darien Center, NY, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Darien Lake Amphitheater (June 3, 2018)',
#   'Event Number': 127,
#   'Latitude': '-78.3861121',
#   'Longitude': '42.9282188',
#   'Popularity': '0.558665',
#   'Start Date': '2018-06-03',
#   'Start Time': '19:30:00',
#   'Venue': 'Darien Lake Amphitheater'},
#  {'City': 'Mansfield, MA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 2 more… at Xfinity Center (June 5, 2018)',
#   'Event Number': 128,
#   'Latitude': '-71.2106493',
#   'Longitude': '41.9944318',
#   'Popularity': '0.212218',
#   'Start Date': '2018-06-05',
#   'Start Time': '19:30:00',
#   'Venue': 'Xfinity Center'},
#  {'City': 'Hartford, CT, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Xfinity Theatre (June 7, 2018)',
#   'Event Number': 129,
#   'Latitude': '-72.6693191',
#   'Longitude': '41.7801718',
#   'Popularity': '0.560029',
#   'Start Date': '2018-06-07',
#   'Start Time': '20:00:00',
#   'Venue': 'Xfinity Theatre'},
#  {'City': 'Camden, NJ, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at BB&T Pavilion (June 8, 2018)',
#   'Event Number': 130,
#   'Latitude': '-75.0004321',
#   'Longitude': '40.0177386',
#   'Popularity': '0.560304',
#   'Start Date': '2018-06-08',
#   'Start Time': '19:30:00',
#   'Venue': 'BB&T Pavilion'},
#  {'City': 'Saratoga Springs, NY, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Saratoga Performing Arts Center (SPAC) (June 9, 2018)',
#   'Event Number': 131,
#   'Latitude': '-73.8055707',
#   'Longitude': '43.0553703',
#   'Popularity': '0.560545',
#   'Start Date': '2018-06-09',
#   'Start Time': '19:30:00',
#   'Venue': 'Saratoga Performing Arts Center (SPAC)'},
#  {'City': 'Clarkston, MI, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at DTE Energy Music Theatre (June 13, 2018)',
#   'Event Number': 132,
#   'Latitude': '-83.380305',
#   'Longitude': '42.7510124',
#   'Popularity': '0.561743',
#   'Start Date': '2018-06-13',
#   'Start Time': '19:30:00',
#   'Venue': 'DTE Energy Music Theatre'},
#  {'City': 'Dover, DE, US',
#   'Event Name': 'Firefly Music Festival 2018',
#   'Event Number': 133,
#   'Latitude': '-75.52437',
#   'Longitude': '39.15817',
#   'Popularity': '0.894635',
#   'Start Date': '2018-06-14',
#   'Start Time': 'None',
#   'Venue': 'The Woodlands, Dover International Speedway'},
#  {'City': 'Tinley Park, IL, US',
#   'Event Name': 'Kendrick Lamar with ScHoolboy Q, SZA, Jay Rock, and 3 more… at Hollywood Casino Amphitheatre (June 15, 2018)',
#   'Event Number': 134,
#   'Latitude': '-87.7711529',
#   'Longitude': '41.5426102',
#   'Popularity': '0.562366',
#   'Start Date': '2018-06-15',
#   'Start Time': '19:30:00',
#   'Venue': 'Hollywood Casino Amphitheatre'},
#  {'City': 'Burgettstown, PA, US',
#   'Event Name': 'Jay Rock, Sir, Ab-Soul, SZA, and 3 more… at Keybank Pavilion (June 16, 2018)',
#   'Event Number': 135,
#   'Latitude': '-80.4342124',
#   'Longitude': '40.4197818',
#   'Popularity': '0.562637',
#   'Start Date': '2018-06-16',
#   'Start Time': '19:30:00',
#   'Venue': 'Keybank Pavilion'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Chris Brown, SZA, and Ella Mai at Staples Center (June 22, 2018)',
#   'Event Number': 136,
#   'Latitude': '-118.2668182',
#   'Longitude': '34.042984',
#   'Popularity': '0.639535',
#   'Start Date': '2018-06-22',
#   'Start Time': '18:00:00',
#   'Venue': 'Staples Center'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Panorama NYC 2018',
#   'Event Number': 137,
#   'Latitude': 'None',
#   'Longitude': 'None',
#   'Popularity': '0.614895',
#   'Start Date': '2018-07-27',
#   'Start Time': 'None',
#   'Venue': "Randall's Island Park"},
#  {'City': 'Cleveland, OH, US',
#   'Event Name': 'InCuya Music Festival 2018',
#   'Event Number': 138,
#   'Latitude': '-81.69436',
#   'Longitude': '41.49932',
#   'Popularity': '0.19823',
#   'Start Date': '2018-08-25',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'Seattle, WA, US',
#   'Event Name': 'Bumbershoot 2018',
#   'Event Number': 139,
#   'Latitude': '-122.3507',
#   'Longitude': '47.62164',
#   'Popularity': '0.651286',
#   'Start Date': '2018-08-31',
#   'Start Time': 'None',
#   'Venue': 'Seattle Center'}]

# %% [markdown]
# # Make Sqlite db of artist name

# %% [markdown]
# import pandas as pd
# import numpy as np
# import os
#
# import sqlalchemy
# from sqlalchemy import create_engine, MetaData
# from sqlalchemy.orm import Session
#
# import pymysql
# pymysql.install_as_MySQLdb()
#
# from sqlalchemy.ext.declarative import declarative_base
#
# from sqlalchemy import Column, Integer, String, Numeric, Text, Float
#
# engine = create_engine("sqlite:///artistname.sqlite")
# conn = engine.connect()

# %% [markdown]
# Base = declarative_base()
#
# class Stations(Base):
#     __tablename__ = 'musicians'
#
#     id = Column(Integer, primary_key=True)
#     station = Column(Text)
#     name = Column(Text)
#     latitude = Column(Float)
#     longitude = Column(Float)
#     elevation = Column(Float)
#
#
# Base.metadata.create_all(engine)

# %% [markdown]
# artists_df = pd.read_csv("static/db/artistlist.csv")
#
# data = artists_df.to_dict(orient='records')

# %% [markdown]
# # Use MetaData from SQLAlchemy to reflect the tables
# metadata = MetaData(bind=engine)
# metadata.reflect()

# %% [markdown]
# artistlist = sqlalchemy.Table('musicians', metadata, autoload=True)

# %% [markdown]
# conn.execute(artistlist.insert(), data)
